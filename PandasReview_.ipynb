# %% [markdown]
# ## Indexing/Selection Refresher

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### First let's make a series named `s` that is the first 6 letters of the alphabet, and give it the indices 49, 48, 47, 0, 1, and 2.

# %%
s = pd.Series(list("abcdef"), index = [49, 48, 47, 0, 1, 2])
s
# Out:
# 49    a
# 48    b
# 47    c
# 0     d
# 1     e
# 2     f
# dtype: object

# %%
f = pandas.Series(list("abcdef"), index = [49, 48, 47, 0, 1, 2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-64e6e4a72c29> in <module>
# ----> 1 f = pandas.Series(list("abcdef"), index = [49, 48, 47, 0, 1, 2])
#
# NameError: name 'pandas' is not defined

# %% [markdown]
# ![locviloc.png](attachment:locviloc.png)

# %%
s.loc[0]
# Out:
# 'd'

# %%
s.iloc[0]
# Out:
# 'a'

# %% [markdown]
# ## Working with Loan Data

# %%
df = pd.read_csv("loanPrediction.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[[609]]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y

# %%
df["ApplicantIncome"].append(.00)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-a8f608874592> in <module>
# ----> 1 df["ApplicantIncome"].append(.00)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in append(self, to_append, ignore_index, verify_integrity)
#    2686             msg = "to_append should be a Series or list/tuple of Series, got DataFrame"
#    2687             raise TypeError(msg)
# -> 2688         return concat(
#    2689             to_concat, ignore_index=ignore_index, verify_integrity=verify_integrity
#    2690         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
#     275         objs,
# ...

# %%
df['ApplicantIncome'] = df['ApplicantIncome'].apply((lambda x: x.ApplicantIncome + .00))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-d92644a7e201> in <module>
# ----> 1 df['ApplicantIncome'] = df['ApplicantIncome'].apply((lambda x: x.ApplicantIncome + .00))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-100-d92644a7e201> in <lambda>(x)
# ----> 1 df['ApplicantIncome'] = df['ApplicantIncome'].apply((lambda x: x.ApplicantIncome + .00))
#
# AttributeError: 'float' object has no attribute 'ApplicantIncome'

# %%
df["ApplicantIncome"] = df["ApplicantIncome"].astype(float)
df["ApplicantIncome"] = df["ApplicantIncome"] + .00
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['ApplicantIncome'] = df['ApplicantIncome'].astype(str)+".00"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    object
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), object(9)
# memory usage: 62.5+ KB

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome       object
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['ApplicantIncome'] = (df['ApplicantIncome'].astype(int))
df['ApplicantIncome'] = (df['ApplicantIncome'].astype(str))

if (df['ApplicantIncome'].str.endswith(".00")):
    df['ApplicantIncome']
else:
        
    df['ApplicantIncome'] + ".00"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-34fdb7a1690c> in <module>
#       2 df['ApplicantIncome'] = (df['ApplicantIncome'].astype(str))
#       3
# ----> 4 if (df['ApplicantIncome'].str.endswith(".00")):
#       5     df['ApplicantIncome']
#       6 else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df['ApplicantIncome'] = (df['ApplicantIncome'].astype(str))+".00"
df['ApplicantIncome'] = (df['ApplicantIncome'].astype(float))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-980af04dcad3> in <module>
#       1 df['ApplicantIncome'] = (df['ApplicantIncome'].astype(str))+".00"
# ----> 2 df['ApplicantIncome'] = (df['ApplicantIncome'].astype(float))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# ...

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ### Check rows and columns of the data

# %%
df.shape
# Out:
# (614, 13)

# %% [markdown]
# ### Generate the descriptive statistics for our data

# %%
df.describe()
# Out:
#        CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# count         614.000000  614.000000        614.000000      614.000000
# mean         1621.245798  146.412162        342.000000        0.842199
# std          2926.248369   84.037468         64.372489        0.349681
# min             0.000000    9.000000         12.000000        0.000000
# 25%             0.000000  100.250000        360.000000        1.000000
# 50%          1188.500000  129.000000        360.000000        1.000000
# 75%          2297.250000  164.750000        360.000000        1.000000
# max         41667.000000  700.000000        480.000000        1.000000
#
#        Loan Amount/Term
# count        614.000000
# mean           0.476115
# std            0.510965
# min            0.025000
# 25%            0.288889
# 50%            0.369444
# 75%            0.506389
# max            9.250000

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df["ApplicantIncome"] = df["ApplicantIncome"].astype(str)
df["ApplicantIncome"] = df["ApplicantIncome"] + ".00"
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 409  LP002317    Male     Yes         3+      Graduate            No
# 333  LP002101    Male     Yes          0      Graduate           NaN
# 171  LP001585    Male     Yes         3+      Graduate            No
# 155  LP001536    Male     Yes         3+      Graduate            No
# 185  LP001640    Male     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 188  LP001644    Male     Yes          0      Graduate           Yes
# 500  LP002603  Female      No          0      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 468  LP002502  Female     Yes          2  Not Graduate           NaN
# 216  LP001722    Male     Yes          0      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.iloc[[608]]
# Out:
#      Loan_ID Gender Married Dependents Education Self_Employed  \
# 77  LP001259   Male     Yes          1  Graduate           Yes
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 77           1000.0             3022.0       110.0             360.0
#
#     Credit_History Property_Area Loan_Status  Loan Amount/Term
# 77             1.0         Urban           N          0.305556

# %%
df.iloc[609]
# Out:
# Loan_ID              LP001644
# Gender                   Male
# Married                   Yes
# Dependents                  0
# Education            Graduate
# Self_Employed             Yes
# ApplicantIncome           674
# CoapplicantIncome        5296
# LoanAmount                168
# Loan_Amount_Term          360
# Credit_History              1
# Property_Area           Rural
# Loan_Status                 Y
# Loan Amount/Term     0.466667
# Name: 188, dtype: object

# %%
df["ApplicantIncome"] = df["ApplicantIncome"].astype(float) 
df["ApplicantIncome"] = df["ApplicantIncome"] + .00
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 409  LP002317    Male     Yes         3+      Graduate            No
# 333  LP002101    Male     Yes          0      Graduate           NaN
# 171  LP001585    Male     Yes         3+      Graduate            No
# 155  LP001536    Male     Yes         3+      Graduate            No
# 185  LP001640    Male     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 188  LP001644    Male     Yes          0      Graduate           Yes
# 500  LP002603  Female      No          0      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 468  LP002502  Female     Yes          2  Not Graduate           NaN
# 216  LP001722    Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
y  = df['ApplicantIncome'] 
y = float(y, 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-dd3238f6c7df> in <module>
#       1 y  = df['ApplicantIncome']
# ----> 2 y = float(y, 2)
#
# TypeError: float expected at most 1 argument, got 2

# %%
df['ApplicantIncome'] = df.apply(lambda y = round(y,2), axis=1
# Out:
#   File "<ipython-input-49-f0ab62c87a70>", line 2
#     df['ApplicantIncome'] = df.apply(lambda y = round(y,2)), axis=1
#                                                           ^
# SyntaxError: invalid syntax

# %%
df['ApplicantIncome'] = round(df['ApplicantIncome'],2)
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 409  LP002317    Male     Yes         3+      Graduate            No
# 333  LP002101    Male     Yes          0      Graduate           NaN
# 171  LP001585    Male     Yes         3+      Graduate            No
# 155  LP001536    Male     Yes         3+      Graduate            No
# 185  LP001640    Male     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 188  LP001644    Male     Yes          0      Graduate           Yes
# 500  LP002603  Female      No          0      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 468  LP002502  Female     Yes          2  Not Graduate           NaN
# 216  LP001722    Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ## Selection

# %% [markdown]
# ### Get the data for the 100th record.

# %%
#df.set_index('Loan_ID')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.iloc[100]
# Out:
# Loan_ID                  LP001345
# Gender                       Male
# Married                       Yes
# Dependents                      2
# Education            Not Graduate
# Self_Employed                  No
# ApplicantIncome              4288
# CoapplicantIncome            3263
# LoanAmount                    133
# Loan_Amount_Term              180
# Credit_History                  1
# Property_Area               Urban
# Loan_Status                     Y
# Name: 100, dtype: object

# %% [markdown]
# ### Get the data for Loan ID LP0001005.

# %%
df.loc[(df['Loan_ID'] == 'LP001005')]
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 2             1.0         Urban           Y

# %% [markdown]
# ### Access all records for the 'LoanAmount' column, first as a Series object, then as a dataframe.
# >- Pandas series are single columns but they always have an index column too

# %%
df['LoanAmount']
# Out:
# 0        NaN
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 614, dtype: float64

# %%
df[['LoanAmount']]
# Out:
#      LoanAmount
# 0           NaN
# 1         128.0
# 2          66.0
# 3         120.0
# 4         141.0
# ..          ...
# 609        71.0
# 610        40.0
# 611       253.0
# 612       187.0
# 613       133.0
#
# [614 rows x 1 columns]

# %% [markdown]
# ### Get all rows of data for `LoanAmount` and `Loan_Amount_Term`.

# %%
df[['LoanAmount', 'Loan_Amount_Term']]
# Out:
#      LoanAmount  Loan_Amount_Term
# 0           NaN             360.0
# 1         128.0             360.0
# 2          66.0             360.0
# 3         120.0             360.0
# 4         141.0             360.0
# ..          ...               ...
# 609        71.0             360.0
# 610        40.0             180.0
# 611       253.0             360.0
# 612       187.0             360.0
# 613       133.0             360.0
#
# [614 rows x 2 columns]

# %%
df.loc[:, ['LoanAmount', 'Loan_Amount_Term']]
# Out:
#      LoanAmount  Loan_Amount_Term
# 0           NaN             360.0
# 1         128.0             360.0
# 2          66.0             360.0
# 3         120.0             360.0
# 4         141.0             360.0
# ..          ...               ...
# 609        71.0             360.0
# 610        40.0             180.0
# 611       253.0             360.0
# 612       187.0             360.0
# 613       133.0             360.0
#
# [614 rows x 2 columns]

# %% [markdown]
# ## Summary Functions

# %% [markdown]
# ### What was the average applicant income?

# %%
df['ApplicantIncome'].mean()
# Out:
# 5403.459283387622

# %% [markdown]
# ### What was the minimum applicant income?

# %%
df['ApplicantIncome'].min()
# Out:
# 150

# %% [markdown]
# ### What was the lowest applicant income for each gender?

# %%
df.groupby(['Gender'])['ApplicantIncome'].min()
# Out:
# Gender
# Female    210
# Male      150
# Name: ApplicantIncome, dtype: int64

# %% [markdown]
# ### What is the overall maximum loan amount?

# %%
df['LoanAmount'].max()
# Out:
# 700.0

# %% [markdown]
# ### Check for nulls in the data, by column.

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# ## Manipulating our Data

# %% [markdown]
# ### Fill the missing values for all numerical variables with the mean

# %%
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].mean())
# sets the loanAmount column equal to the loanAmount column filled with the mean 
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())

df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mean())

# %% [markdown]
# ### Fill the missing values for the categorical variables with the mode.

# %%
x = df['Gender'].mode()
x
# Out:
# 0    Male
# dtype: object

# %%
x[0]
# Out:
# 'Male'

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
df['Married'] = df['Married'].fillna(df['Married'].mode()[0])
df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])

# %% [markdown]
# ### Make sure there are no null values left

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# ### Sort the dataframe from lowest to highest loan amount.

# %%
df.sort_values(by='LoanAmount')
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 568  LP002840  Female      No          0      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# 94   LP001325    Male      No          0  Not Graduate            No
# 133  LP001482    Male     Yes          0      Graduate           Yes
# 555  LP002792    Male     Yes          1      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 369  LP002191    Male     Yes          0      Graduate            No
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 155  LP001536    Male     Yes         3+      Graduate            No
# 130  LP001469    Male      No          0      Graduate           Yes
# 171  LP001585    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ### Sort it from highest to lowest applicant income.

# %%
df.sort_values(by='ApplicantIncome', ascending = False, inplace = True)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 409  LP002317    Male     Yes         3+      Graduate            No
# 333  LP002101    Male     Yes          0      Graduate           NaN
# 171  LP001585    Male     Yes         3+      Graduate            No
# 155  LP001536    Male     Yes         3+      Graduate            No
# 185  LP001640    Male     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 188  LP001644    Male     Yes          0      Graduate           Yes
# 500  LP002603  Female      No          0      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 468  LP002502  Female     Yes          2  Not Graduate           NaN
# 216  LP001722    Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ### Create a new column, the loan amount over the term of the loan.

# %%
df['Loan Amount/Term'] = df['LoanAmount']/df['Loan_Amount_Term']

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 409  LP002317    Male     Yes         3+      Graduate            No
# 333  LP002101    Male     Yes          0      Graduate           NaN
# 171  LP001585    Male     Yes         3+      Graduate            No
# 155  LP001536    Male     Yes         3+      Graduate            No
# 185  LP001640    Male     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 188  LP001644    Male     Yes          0      Graduate           Yes
# 500  LP002603  Female      No          0      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 468  LP002502  Female     Yes          2  Not Graduate           NaN
# 216  LP001722    Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
