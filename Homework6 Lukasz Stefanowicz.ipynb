# %% [markdown]
# # Homework 6, due April 10

# %% [markdown]
# ## Import necessary modules, then read in the JEOPARDY_CSV file.

# %%
import pandas as pd
import numpy as np
jep=pd.read_csv('JEOPARDY_CSV.csv')
jep
# Out:
#         Show Number    Air Date             Round  \
# 0              4680  12/31/2004         Jeopardy!
# 1              4680  12/31/2004         Jeopardy!
# 2              4680  12/31/2004         Jeopardy!
# 3              4680  12/31/2004         Jeopardy!
# 4              4680  12/31/2004         Jeopardy!
# ...             ...         ...               ...
# 216925         4999   5/11/2006  Double Jeopardy!
# 216926         4999   5/11/2006  Double Jeopardy!
# 216927         4999   5/11/2006  Double Jeopardy!
# 216928         4999   5/11/2006  Double Jeopardy!
# 216929         4999   5/11/2006   Final Jeopardy!
#
#                                Category    Value  \
# 0                               HISTORY    $200
# 1       ESPN's TOP 10 ALL-TIME ATHLETES    $200
# 2           EVERYBODY TALKS ABOUT IT...    $200
# 3                      THE COMPANY LINE    $200
# 4                   EPITAPHS & TRIBUTES    $200
# ...                                 ...      ...
# ...

# %% [markdown]
# ## 1. Display the first 20 rows of the data and the descriptive analytics table (first the default) and then for all columns.

# %%
jep.head(20)
# Out:
#     Show Number    Air Date      Round                         Category  \
# 0          4680  12/31/2004  Jeopardy!                          HISTORY
# 1          4680  12/31/2004  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES
# 2          4680  12/31/2004  Jeopardy!      EVERYBODY TALKS ABOUT IT...
# 3          4680  12/31/2004  Jeopardy!                 THE COMPANY LINE
# 4          4680  12/31/2004  Jeopardy!              EPITAPHS & TRIBUTES
# 5          4680  12/31/2004  Jeopardy!                   3-LETTER WORDS
# 6          4680  12/31/2004  Jeopardy!                          HISTORY
# 7          4680  12/31/2004  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES
# 8          4680  12/31/2004  Jeopardy!      EVERYBODY TALKS ABOUT IT...
# 9          4680  12/31/2004  Jeopardy!                 THE COMPANY LINE
# 10         4680  12/31/2004  Jeopardy!              EPITAPHS & TRIBUTES
# 11         4680  12/31/2004  Jeopardy!                   3-LETTER WORDS
# ...

# %%
jep.describe()
# Out:
#          Show Number
# count  216930.000000
# mean     4264.238519
# std      1386.296335
# min         1.000000
# 25%      3349.000000
# 50%      4490.000000
# 75%      5393.000000
# max      6300.000000

# %%
jep.describe(include='all')
# Out:
#           Show Number   Air Date      Round        Category   Value  \
# count   216930.000000     216930     216930          216930  216930
# unique            NaN       3640          4           27983     146
# top               NaN  5/19/1997  Jeopardy!  BEFORE & AFTER   $400
# freq              NaN         62     107384             547   42244
# mean      4264.238519        NaN        NaN             NaN     NaN
# std       1386.296335        NaN        NaN             NaN     NaN
# min          1.000000        NaN        NaN             NaN     NaN
# 25%       3349.000000        NaN        NaN             NaN     NaN
# 50%       4490.000000        NaN        NaN             NaN     NaN
# 75%       5393.000000        NaN        NaN             NaN     NaN
# max       6300.000000        NaN        NaN             NaN     NaN
#
#             Question  Answer
# count         216930  216928
# unique        216123   88236
# top     [audio clue]   China
# freq              17     216
# ...

# %% [markdown]
# ## 2. Pull out all of the different `Round` names and store them in a list (you can call the `.tolist()` function to convert the extracted object.)

# %%
#get unique rounds and set to list
round_names = jep[' Round'].unique().tolist()
round_names
# Out:
# ['Jeopardy!', 'Double Jeopardy!', 'Final Jeopardy!', 'Tiebreaker']

# %% [markdown]
# ## 3. Make a dictionary with the round names and their respective top categories.

# %%
d = {}
# loop through unique rounds and add top category of each round to dict
for item in round_names:
    d[item] = jep.loc[jep[' Round'] == item][' Category'].mode()[0]

# %%
d
# Out:
# {'Jeopardy!': 'POTPOURRI',
#  'Double Jeopardy!': 'BEFORE & AFTER',
#  'Final Jeopardy!': 'U.S. PRESIDENTS',
#  'Tiebreaker': "CHILD'S PLAY"}

# %% [markdown]
# ## 4. How many unique categories are there? Include a print statement with some example categories (pulled from the data - don't type them in.)
#
# **Did you know there were this many? Which would you be best at?**

# %%
print("There are", jep[' Category'].nunique(), "unique categories")
print("Here are some examples:")
# print the first 10 of the unique categories list
print(jep[' Category'].unique()[:10])
# Out:
# There are 27983 unique categories
# Here are some examples:
# ['HISTORY' "ESPN's TOP 10 ALL-TIME ATHLETES" 'EVERYBODY TALKS ABOUT IT...'
#  'THE COMPANY LINE' 'EPITAPHS & TRIBUTES' '3-LETTER WORDS'
#  'DR. SEUSS AT THE MULTIPLEX' 'PRESIDENTIAL STATES OF BIRTH'
#  'AIRLINE TRAVEL' 'THAT OLD-TIME RELIGION']

# %% [markdown]
# ## 5. Do "cats" or "dogs" come up more frequently in the questions?
# * Hint: `.str.contains()` can be used on the questions you get from the data

# %%
# store total of cats and dogs occurences, then compare the two
cats = jep[' Question'].str.contains("cats").sum()
dogs = jep[' Question'].str.contains("dogs").sum()
if cats > dogs:
    print("Cats")
else:
    print("Dogs")
# Out:
# Dogs

# %% [markdown]
#  ## 6. You may have noticed something funky with the column names by now (if you haven't, call `.columns` on the data.) Change them to not have that space at the beginning. Use a lambda function that strips that first space (remember, `.rstrip()` and `.lstrip()` will strip the characters at the right/left). You can then call the `.rename()` function on the original dataframe, and pass in the function you just defined for `columns` - don't forget the `inplace` parameter to actually change the dataframe.

# %%
#rename columns by stripping white space
jep.rename(columns=lambda x: x.strip(), inplace=True)
jep.columns.tolist()
# Out:
# ['Show Number', 'Air Date', 'Round', 'Category', 'Value', 'Question', 'Answer']

# %% [markdown]
# ## 7. Change the `Value` column to remove all dollar signs.

# %%
# replace all $ in value column with nothing
jep['Value'] = jep['Value'].str.replace("$", "")
jep.head(20)
# Out:
#     Show Number    Air Date      Round                         Category Value  \
# 0          4680  12/31/2004  Jeopardy!                          HISTORY  200
# 1          4680  12/31/2004  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  200
# 2          4680  12/31/2004  Jeopardy!      EVERYBODY TALKS ABOUT IT...  200
# 3          4680  12/31/2004  Jeopardy!                 THE COMPANY LINE  200
# 4          4680  12/31/2004  Jeopardy!              EPITAPHS & TRIBUTES  200
# 5          4680  12/31/2004  Jeopardy!                   3-LETTER WORDS  200
# 6          4680  12/31/2004  Jeopardy!                          HISTORY  400
# 7          4680  12/31/2004  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  400
# 8          4680  12/31/2004  Jeopardy!      EVERYBODY TALKS ABOUT IT...  400
# 9          4680  12/31/2004  Jeopardy!                 THE COMPANY LINE  400
# 10         4680  12/31/2004  Jeopardy!              EPITAPHS & TRIBUTES  400
# ...

# %% [markdown]
# ## 8. Display all the rows of data for the `People` category. Choose a few words and compare their frequencies in this category of questions.

# %%
# first get data where category is people
people = jep[jep['Category'] == "PEOPLE"]
people
# Out:
#         Show Number   Air Date             Round Category   Value  \
# 1066           4085  5/10/2002         Jeopardy!   PEOPLE    200
# 1072           4085  5/10/2002         Jeopardy!   PEOPLE    400
# 1078           4085  5/10/2002         Jeopardy!   PEOPLE    600
# 1084           4085  5/10/2002         Jeopardy!   PEOPLE    800
# 1090           4085  5/10/2002         Jeopardy!   PEOPLE  1,000
# ...             ...        ...               ...      ...     ...
# 209870         1164  9/28/1989  Double Jeopardy!   PEOPLE    400
# 209876         1164  9/28/1989  Double Jeopardy!   PEOPLE    600
# 209881         1164  9/28/1989  Double Jeopardy!   PEOPLE    800
# 209886         1164  9/28/1989  Double Jeopardy!   PEOPLE  1,000
# 216086         4364  7/17/2003   Final Jeopardy!   PEOPLE    None
#
#                                                  Question  \
# 1066    This wrestler nicknamed his daughter born in A...
# 1072    Fatally, American groupie Nancy Spungen was th...
# ...

# %%
# look at occurences of different words in people category
print(people["Question"].str.contains("she").sum())
print(people["Question"].str.contains("dog").sum())
print(people["Question"].str.contains(" he").sum())
print(people["Question"].str.contains("the").sum())
# Out:
# 20
# 1
# 73
# 150

# %% [markdown]
# ## 9. What is the least common category of questions?

# %%
jep["Category"].min()
# Out:
# ' A JIM CARREY FILM FESTIVAL'

# %% [markdown]
# ## 10. Show all questions from 2000 and tell me what the top category was for that year.
# >- Hint: apply the `.str.endswith()` method

# %%
# first get questions where 2000 is the year
year2000 = jep.loc[jep['Air Date'].str.endswith('2000')]
year2000['Question'].tolist()
# Out:
# ['Prime Minister Tony Blair dubbed her "The People\'s Princess"',
#  'Once Tommy Mullaney on "L.A. Law", John Spencer now plays White House chief of staff Leo McGarry on this series',
#  "The Cinderella Castle Mystery Tour is a highlight of this Asian city's Disneyland",
#  'This punk rock hitmaker heard here has had numerous hits on both sides of the Atlantic',
#  '"Conrad begins (and ends) Marlow\'s journey... on the Thames, on the yawl, Nellie", says the foreword to this novel',
#  "We'll look smart in these vehicles that returned to London in 1999",
#  'She was "The Untamed Heifer" & "The Virgin Queen"',
#  'Barbra Streisand knows he played Lt. Col. Bill "Raider" Kelly on "Pensacola: Wings of Gold"',
#  'The home of silk merchant Jim Thompson, who disappeared in 1967, is a tourist attraction in this Thai city',
#  'Czar at 17, he was famous for extraordinary sadism & cruelty, even as a boy',
# ...

# %%
# then find category that appeared the most
year2000["Category"].mode()[0]
# Out:
# 'BEFORE & AFTER'
