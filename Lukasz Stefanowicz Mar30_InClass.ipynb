# %% [markdown]
# # Week 12
# ## In-Class Activity

# %% [markdown]
# ## Creating a `squirrel` DataFrame
# >- Complete the following steps to practice reading in a csv file
# >>- Note: You should download the `squirrel.csv` file from Canvas and save it in the same director/folder that you have this notebook saved in
# 1. Import the pandas module and alias it `pd`

# %% [markdown]
# ### Step 1: Check your working directory and make sure you have the `squirrel.csv`  file there

# %%
pwd
# Out:
# 'C:\\Users\\lukasz\\Desktop\\BAIM 3220 Python'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 8650-7A23
#
#  Directory of C:\Users\lukasz\Desktop\BAIM 3220 Python
#
# 05/08/2021  08:09 AM    <DIR>          .
# 05/08/2021  08:09 AM    <DIR>          ..
# 05/08/2021  08:09 AM    <DIR>          .ipynb_checkpoints
# 04/17/2021  10:07 AM        15,349,323 complete.csv
# 04/20/2021  09:28 AM               485 customer.csv
# 04/21/2021  05:16 PM            49,774 foodplot4.png
# 03/30/2021  09:57 AM             3,837 Future50.csv
# 04/20/2021  09:28 AM               206 invoice.csv
# 04/01/2021  08:52 AM        33,633,170 JEOPARDY_CSV.csv
# 04/20/2021  09:28 AM               496 line.csv
# 04/13/2021  09:31 AM            38,013 loans.csv
# 03/30/2021  10:48 AM            54,263 Lukasz Stefanowicz Mar30_InClass.ipynb
# 04/17/2021  11:15 AM             5,761 LukaszStefanowiczQuiz3NEW.ipynb
# 04/29/2021  01:04 PM            20,726 ManipulatingStrings_TypeAlong_.ipynb
# 04/19/2021  03:40 PM         1,008,821 merged.ipynb
# ...

# %% [markdown]
# ### Step 2: import the `pandas` module and alias it `pd`

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 3: Read the `squirrel.csv` file into a pandas dataframe named, `squ`
# >- Look at the first five records to make sure `stu` is imported correctly

# %%
squ=pd.read_csv('squirrel.csv')
squ
# Out:
#               X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0    -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1    -73.968857  40.783783     21B-AM-1019-04     21B    AM  10192018
# 2    -73.974281  40.775534     11B-PM-1014-08     11B    PM  10142018
# 3    -73.959641  40.790313     32E-PM-1017-14     32E    PM  10172018
# 4    -73.970268  40.776213     13E-AM-1017-05     13E    AM  10172018
# ...         ...        ...                ...     ...   ...       ...
# 3018 -73.963943  40.790868     30B-AM-1007-04     30B    AM  10072018
# 3019 -73.970402  40.782560     19A-PM-1013-05     19A    PM  10132018
# 3020 -73.966587  40.783678     22D-PM-1012-07     22D    PM  10122018
# 3021 -73.963994  40.789915     29B-PM-1010-02     29B    PM  10102018
# 3022 -73.975479  40.769640      5E-PM-1012-01     05E    PM  10122018
#
#       Hectare Squirrel Number    Age Primary Fur Color  \
# 0                           3    NaN               NaN
# ...

# %% [markdown]
# #### Show the last five records of `squ`

# %%
squ.tail(5)
# Out:
#               X          Y Unique Squirrel ID Hectare Shift      Date  \
# 3018 -73.963943  40.790868     30B-AM-1007-04     30B    AM  10072018
# 3019 -73.970402  40.782560     19A-PM-1013-05     19A    PM  10132018
# 3020 -73.966587  40.783678     22D-PM-1012-07     22D    PM  10122018
# 3021 -73.963994  40.789915     29B-PM-1010-02     29B    PM  10102018
# 3022 -73.975479  40.769640      5E-PM-1012-01     05E    PM  10122018
#
#       Hectare Squirrel Number    Age Primary Fur Color  \
# 3018                        4  Adult              Gray
# 3019                        5  Adult              Gray
# 3020                        7  Adult              Gray
# 3021                        2    NaN              Gray
# 3022                        1  Adult          Cinnamon
#
#          Highlight Fur Color  ...   Kuks  Quaas  Moans Tail flags  \
# 3018                     NaN  ...  False  False  False      False
# 3019                   White  ...  False  False  False      False
# ...

# %% [markdown]
# #### Show a tuple of the number of columns and rows in `squ`

# %%
squ.shape
# Out:
# (3023, 31)

# %% [markdown]
# #### Show the columns in `squ`

# %%
squ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3023 entries, 0 to 3022
# Data columns (total 31 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   X                                           3023 non-null   float64
#  1   Y                                           3023 non-null   float64
#  2   Unique Squirrel ID                          3023 non-null   object
#  3   Hectare                                     3023 non-null   object
#  4   Shift                                       3023 non-null   object
#  5   Date                                        3023 non-null   int64
#  6   Hectare Squirrel Number                     3023 non-null   int64
#  7   Age                                         2902 non-null   object
#  8   Primary Fur Color                           2968 non-null   object
#  9   Highlight Fur Color                         1937 non-null   object
# ...

# %% [markdown]
# #### Show the datatypes that are in `squ`

# %%
squ.dtypes
# Out:
# X                                             float64
# Y                                             float64
# Unique Squirrel ID                             object
# Hectare                                        object
# Shift                                          object
# Date                                            int64
# Hectare Squirrel Number                         int64
# Age                                            object
# Primary Fur Color                              object
# Highlight Fur Color                            object
# Combination of Primary and Highlight Color     object
# Color notes                                    object
# Location                                       object
# Above Ground Sighter Measurement               object
# Specific Location                              object
# Running                                          bool
# Chasing                                          bool
# ...

# %% [markdown]
# ### Show a list of the unique 'Primary Fur Color' values

# %% [markdown]
# ### Show how many unique 'Primary Fur Color' values there

# %%
len(squ['Primary Fur Color'].unique())
# Out:
# 4

# %% [markdown]
# ### Based on a descriptive analytics table for `squ`, what was the top Primary Fur Color?

# %%
squ['Primary Fur Color'].describe()
# Out:
# count     2968
# unique       3
# top       Gray
# freq      2473
# Name: Primary Fur Color, dtype: object

# %% [markdown]
# ### Add a new column` Tail Flags/Twitches` to `squ` that stores the result of Tail flags/Tail twitches.

# %%
squ['Hectare Squared']=squ[['Hectare Squirrel Number']].applymap(np.square)

# %% [markdown]
# ### Show me the dataframe with the new column added

# %%
squ
# Out:
#               X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0    -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1    -73.968857  40.783783     21B-AM-1019-04     21B    AM  10192018
# 2    -73.974281  40.775534     11B-PM-1014-08     11B    PM  10142018
# 3    -73.959641  40.790313     32E-PM-1017-14     32E    PM  10172018
# 4    -73.970268  40.776213     13E-AM-1017-05     13E    AM  10172018
# ...         ...        ...                ...     ...   ...       ...
# 3018 -73.963943  40.790868     30B-AM-1007-04     30B    AM  10072018
# 3019 -73.970402  40.782560     19A-PM-1013-05     19A    PM  10132018
# 3020 -73.966587  40.783678     22D-PM-1012-07     22D    PM  10122018
# 3021 -73.963994  40.789915     29B-PM-1010-02     29B    PM  10102018
# 3022 -73.975479  40.769640      5E-PM-1012-01     05E    PM  10122018
#
#       Hectare Squirrel Number    Age Primary Fur Color  \
# 0                           3    NaN               NaN
# ...
